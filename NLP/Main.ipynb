# %%
# coding: utf-8
import os
from SimpleNLP import SimpleCorpusProcessor

# %%
pwd = os.getcwd()
corpus_path = os.path.join(pwd, "corpus/")
corpus = {}
for root, dirs, files in os.walk(corpus_path):
    for file in files:
        if '.txt' in file:
            path = os.path.join(root, file)
            with open(path, 'r', encoding="utf8") as fp:
                doc = fp.readlines()[0]
            key = file.replace('.txt', '')
            corpus[key] = doc

corpus = SimpleCorpusProcessor(corpus, remove_marks=True)
tf = corpus.TermFrequencies()
# tf.to_csv(pwd + '/TermFrequencies.csv', encoding='utf-8')

df = corpus.DocumentFrequencies()
# df.to_csv(pwd + '/DocumentFreguencies.csv', encoding='utf-8')

tfidf = corpus.TFIDF()
# df.to_csv(pwd + '/TFIDF.csv', encoding='utf-8')

# %%
print(list(tf.columns))
# Out:
# ['apple developing high end headphones', 'china coronavirus qr code intl hnk', 'coronavirus remdesivir trial', 'coronavirus test using crispr detects disease in under 40 minutes']

# %%
tf.sort_values(list(tf.columns))
# Out:
#         apple developing high end headphones  \
# وخامت                                    0.0
# یافتن                                    0.0
# پاندمی                                   0.0
# های                                      0.0
# معتبر                                    0.0
# ...                                      ...
# از                                       1.0
# این                                      1.0
# که                                       1.0
# اپل                                      2.0
# هدفون                                    2.0
#
#         china coronavirus qr code intl hnk  coronavirus remdesivir trial  \
# وخامت                                  0.0                           0.0
# یافتن                                  0.0                           0.0
# پاندمی                                 0.0                           0.0
# های                                    0.0                           0.0
# معتبر                                  0.0                           0.0
# ...                                    ...                           ...
# از                                     1.0                           0.0
# این                                    2.0                           0.0
# که                                     2.0                           2.0
# اپل                                    0.0                           0.0
# هدفون                                  0.0                           0.0
#
#         coronavirus test using crispr detects disease in under 40 minutes
# وخامت                                                 1.0
# یافتن                                                 1.0
# پاندمی                                                1.0
# های                                                   1.0
# معتبر                                                 1.0
# ...                                                   ...
# از                                                    1.0
# این                                                   1.0
# که                                                    1.0
# اپل                                                   0.0
# هدفون                                                 0.0
#
# [141 rows x 4 columns]

# %%
df.head(20)
# Out:
#        Frequency
# که             4
# این            3
# از             3
# به             3
# در             3
# برای           2
# سرعت           2
# با             2
# زندگی          2
# میشود          2
# و              2
# می             2
# ۱۹             2
# کووید          2
# حال            2
# هستند          2
# های            1
# معتبر          1
# اپل            1
# دقیق           1
